# %% [markdown]
# **Užduotį atliko:**
# Pijus Zlatkus 2110648

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dirbtinis neuronas su ADALINE mokymosi taisykle ir SGD

# %% [markdown]
# Neurono mokymui naudotas stochastinis gradientinis nusileidimas ir ADALINE mokymo taisyklė.

# %%
class AdalineSGD:
    # Konstruktorius su parametrais: mokymo greitis, epochų skaičius ir atsitiktinių skaičių generatoriaus pradinė padėtis.
    def __init__(self, learning_rate=0.01, epochs=50, random_state=10):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.random_state = random_state # Atsitiktinių skaičių generatoriaus pradinė padėtis
        self.weights = None
        self.bias = None
        self.loss = []
        self.accuracy = []

    # Mokymo funkcija, kuri atnaujina svorius naudojant stochastinį gradientinį nusileidimą.
    def fit(self, X, y, E_min):
        rgen = np.random.RandomState(self.random_state) # Sukuriame atsitiktinių skaičių generatorių
        self.weights = rgen.normal(loc=0.0, scale=0.01, size=X.shape[1]) # Inicializuojame svorius mažais atsitiktiniais skaičiais
        self.bias = 1.
        self.loss = []
        self.accuracy = []

        # Pradedame mokymo procesą, kuris vyks iki nurodyto epochų skaičiaus arba kol pasieksime minimalią paklaidą
        for epoch in range(self.epochs):
            X, y = shuffle(X, y, random_state=self.random_state)
            loss = 0

            # Iteruojame per kiekvieną mokymo duomenų pavyzdį
            for x, target in zip(X, y):
                output = self.neuron_input(x) # Apskaičiuojame neurono išvestį
                error = (target - output) # Apskaičiuojame paklaidą
                self.weights += self.learning_rate * x.dot(error) # Atnaujiname svorius
                self.bias += self.learning_rate * error
                loss += 0.5 * error**2 # Skaičiuojame paklaidos kvadratą ir jį pridedame prie bendros paklaidos
                

            avg_loss = loss / len(y)
            self.loss.append(avg_loss)
            self.accuracy.append(self.calculate_accuracy(X, y))
            if avg_loss <= E_min:  # Jeigu vidutinė paklaida mažesnė ar lygi nustatytam slenksiui, stabdome mokymo procesą
                print(f"Mokymasis sustabdytas {epoch+1} epochoje, nes pasiektas minimalus paklaidos slenkstis.")
                break

        return self

    # Funkcija, kuri apskaičiuoja bendrą svorių ir įvesties daugybą ir poslinkį.
    def neuron_input(self, X):
        return np.dot(X, self.weights) + self.bias

    # Prognozavimo funkcija, kuri klasifikuoja pateiktus duomenis kažkuriai klasei
    def predict(self, X):
        return np.where(self.neuron_input(X) >= 0.5, 1, 0)
    
    # Funkcija kuri skaičiuoja neurono prognozių tikslumą
    def calculate_accuracy(self, X, y):
        predictions = self.predict(X)
        accuracy = np.mean(predictions == y)
        return accuracy
    
    # Funkcija kuri skaičiuoja neurono prognozių vidutinę kvadratinę paklaidą
    def calculate_MSE(self, X, y):
        predictions = self.predict(X)
        errors = y - predictions
        mse = np.mean(errors**2)
        return mse

# %% [markdown]
# ## Duomenų užkrovimas ir padalinimas į mokymosi ir testavimo aibes

# %%
# Funkcija, kuri užkrauna duomenis iš failo ir padalina į mokymosi ir testavimo aibes
def load_and_split_data(file_path, test_size=0.3):
    data = pd.read_csv(file_path, header=None, delimiter=';')
    X, y = data.iloc[:, :-1].values, data.iloc[:, -1].values
    
    scaler = StandardScaler()
    X = scaler.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=10)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Pagalbinės funkcijos apskaičiuojančios metrikas

# %%
# Funkcija kiekvienam testavimo duomenų įrašui nurodyti, kokias klases nustatė neuronas ir kokia turėjo būti.
def test_data_evaluation(X_test, y_test, model):
    predictions = model.predict(X_test)
    print("Testavimo duomenų įrašų klasifikacija:")
    for i, (pred, actual) in enumerate(zip(predictions, y_test)):
        print(f"Įrašas {i+1}: Nustatyta klasė = {pred}, Turėjo būti = {actual}")

# Funkcija atliekanti eksperimentą ir apskaičiuojanti visas metrikas
def run_experiment(data_file_path, learning_rate, epochs, E_min):
    X_train, X_test, y_train, y_test = load_and_split_data(data_file_path)
    adaline = AdalineSGD(learning_rate=learning_rate, epochs=epochs)
    adaline.fit(X_train, y_train, E_min)

    epochs_range = range(1, len(adaline.loss) + 1)
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, adaline.loss, color='red', label='Paklaida')
    plt.xlabel('Epocha')
    plt.ylabel('Paklaida')
    plt.title(f'Mokymosi greitis: {learning_rate}')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, adaline.accuracy, color='blue', label='Tikslumas')
    plt.xlabel('Epocha')
    plt.ylabel('Tikslumas')
    plt.title(f'Mokymosi greitis: {learning_rate}')
    plt.legend()

    plt.tight_layout()
    plt.show()

    print(f"Epochų skaičius: {adaline.epochs}")
    print(f"Svoriai: {adaline.weights}")
    print(f"Poslinkis: {adaline.bias}")
    print(f"Mokymo duomenų tikslumas: {adaline.accuracy[-1]}")
    print(f"Mokymo duomenų paklaida: {adaline.loss[-1]}")
    print(f"Testavimo duomenų tikslumas: {adaline.calculate_accuracy(X_test, y_test)}")
    print(f"Testavimo duomenų paklaida: {adaline.calculate_MSE(X_test, y_test)}")
    print("\n\n")

    test_data_evaluation(X_test, y_test, adaline)

# %% [markdown]
# ## Eksperimentas su irisų duomenimis

# %%
print("Eksperimentas su Irisų duomenimis:")
data_file_path = 'iris-data.csv'
learning_rate = 0.0001
epochs = 100
E_min = 0.01

run_experiment(data_file_path, learning_rate, epochs, E_min)
# Out:
# Eksperimentas su Irisų duomenimis:
# Epochų skaičius: 100
# Svoriai: [0.06621144 0.01871975 0.11996572 0.15905982]
# Poslinkis: 0.7470339782190382
# Mokymo duomenų tikslumas: 0.7142857142857143
# Mokymo duomenų paklaida: 0.07976580716698738
# Testavimo duomenų tikslumas: 0.8
# Testavimo duomenų paklaida: 0.2
#
#
#
# Testavimo duomenų įrašų klasifikacija:
# Įrašas 1: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 2: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 3: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 4: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 5: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 6: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 7: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 8: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 9: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 10: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 11: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 12: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 13: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 14: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 15: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 16: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 17: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 18: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 19: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 20: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 21: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 22: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 23: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 24: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 25: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 26: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 27: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 28: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 29: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 30: Nustatyta klasė = 1, Turėjo būti = 1

# %% [markdown]
# ## Eksperimentas su krūties vėžio duomenimis

# %%
print("Eksperimentas su krūtų vėžio duomenimis:")
data_file_path = 'breast-cancer-data.csv'
learning_rate = 0.001
epochs = 100
E_min = 0.01

run_experiment(data_file_path, learning_rate, epochs, E_min)
# Out:
# Eksperimentas su krūtų vėžio duomenimis:
# Epochų skaičius: 100
# Svoriai: [0.09867365 0.03579249 0.05001816 0.02471733 0.03366868 0.16372938
#  0.06031235 0.06170386 0.01170531]
# Poslinkis: 0.3527550999547938
# Mokymo duomenų tikslumas: 0.9644351464435147
# Mokymo duomenų paklaida: 0.017494195663526585
# Testavimo duomenų tikslumas: 0.9658536585365853
# Testavimo duomenų paklaida: 0.03414634146341464
#
#
#
# Testavimo duomenų įrašų klasifikacija:
# Įrašas 1: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 2: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 3: Nustatyta klasė = 0, Turėjo būti = 1
# Įrašas 4: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 5: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 6: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 7: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 8: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 9: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 10: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 11: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 12: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 13: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 14: Nustatyta klasė = 0, Turėjo būti = 1
# Įrašas 15: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 16: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 17: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 18: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 19: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 20: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 21: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 22: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 23: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 24: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 25: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 26: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 27: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 28: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 29: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 30: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 31: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 32: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 33: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 34: Nustatyta klasė = 0, Turėjo būti = 1
# Įrašas 35: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 36: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 37: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 38: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 39: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 40: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 41: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 42: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 43: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 44: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 45: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 46: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 47: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 48: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 49: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 50: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 51: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 52: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 53: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 54: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 55: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 56: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 57: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 58: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 59: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 60: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 61: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 62: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 63: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 64: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 65: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 66: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 67: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 68: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 69: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 70: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 71: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 72: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 73: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 74: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 75: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 76: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 77: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 78: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 79: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 80: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 81: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 82: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 83: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 84: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 85: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 86: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 87: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 88: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 89: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 90: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 91: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 92: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 93: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 94: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 95: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 96: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 97: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 98: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 99: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 100: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 101: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 102: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 103: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 104: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 105: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 106: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 107: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 108: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 109: Nustatyta klasė = 0, Turėjo būti = 1
# Įrašas 110: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 111: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 112: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 113: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 114: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 115: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 116: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 117: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 118: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 119: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 120: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 121: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 122: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 123: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 124: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 125: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 126: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 127: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 128: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 129: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 130: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 131: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 132: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 133: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 134: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 135: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 136: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 137: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 138: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 139: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 140: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 141: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 142: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 143: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 144: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 145: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 146: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 147: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 148: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 149: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 150: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 151: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 152: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 153: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 154: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 155: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 156: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 157: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 158: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 159: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 160: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 161: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 162: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 163: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 164: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 165: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 166: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 167: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 168: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 169: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 170: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 171: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 172: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 173: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 174: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 175: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 176: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 177: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 178: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 179: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 180: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 181: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 182: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 183: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 184: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 185: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 186: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 187: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 188: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 189: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 190: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 191: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 192: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 193: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 194: Nustatyta klasė = 1, Turėjo būti = 0
# Įrašas 195: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 196: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 197: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 198: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 199: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 200: Nustatyta klasė = 0, Turėjo būti = 1
# Įrašas 201: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 202: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 203: Nustatyta klasė = 0, Turėjo būti = 0
# Įrašas 204: Nustatyta klasė = 1, Turėjo būti = 1
# Įrašas 205: Nustatyta klasė = 0, Turėjo būti = 0
